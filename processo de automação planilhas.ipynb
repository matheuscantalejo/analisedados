# %%
# !pip install pyautogui
# !pip install pyperclip

# %%
import pyautogui
import pyperclip
import time

pyautogui.hotkey("win")
time.sleep(3)
pyautogui.write("publica")
time.sleep(1)
pyautogui.press("enter")
time.sleep(3)
pyautogui.click(x=1107, y=65)
time.sleep(3)
pyautogui.write("2022")
pyautogui.press("enter")
time.sleep(2)
pyautogui.click(x=424, y=122,clicks=2)

# %% [markdown]
# ##

# %%
time.sleep (5)
pyautogui.position()
# Out:
# Point(x=424, y=122)

# %%
import pandas as pd

# %%
tabela = pd.read_excel(r"Z:\2022\02 Fevereiro.xlsx")
display(tabela)
# Out:
#    Data Emissao  Numero NF                         Vencto  \
# 0           NaT        NaN                            NaN
# 1           NaT        NaN                            NaN
# 2    2022-02-01     1937.0            2022-02-22 00:00:00
# 3    2022-02-02     1938.0            2022-03-02 00:00:00
# 4    2022-02-02     1939.0              02/03 09/03 16/03
# 5    2022-02-02     1940.0            2022-03-02 00:00:00
# 6    2022-02-03     1943.0            2022-03-03 00:00:00
# 7    2022-02-03     1944.0        03/03 10/03 17/03 24/03
# 8    2022-02-04     1945.0            2022-03-04 00:00:00
# 9    2022-02-07     1946.0            2022-03-07 00:00:00
# 10   2022-02-07     1947.0            2022-02-07 00:00:00
# 11   2022-02-07     1948.0            2022-03-08 00:00:00
# 12   2022-02-08     1949.0        08/03 29/03 12/04 03/05
# 13   2022-02-08     1950.0            2022-03-08 00:00:00
# 14   2022-02-10     1951.0            2022-02-10 00:00:00
# ...
